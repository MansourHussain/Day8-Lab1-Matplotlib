# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1: Create two charts using list and dataframe

# %%
plt.plot([5,6,7,9,11])

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
x = [40,30,20,70]
plt.pie(x, explode=[0.2,0.2,0.2,0.2]);

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
w = np.random.randn(100)
z = np.random.randn(100)
plt.scatter(w,z, alpha=0.4, s=50);

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
x = plt.plot([1,2,3,4])
y = plt.plot([6,6,7,9])
plt.legend(['2010', '2018'])
plt.title('Sales', fontsize=30, loc = 'center', color='b')
# Out:
# Text(0.5, 1.0, 'Sales')

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors

# %%
x = plt.plot([1,2,3,4])
y = plt.plot([6,6,7,7.3])
m = plt.plot([5.5,6.8,7.6,10])
plt.legend(['2010', '2018', '2022'])
plt.title('Sales', fontsize=30, loc = 'center', color='b')
# Out:
# Text(0.5, 1.0, 'Sales')

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10

# %%
plt.figure(figsize=[20,5])
plt.suptitle('Subplots',fontsize = 16)

# Share a X axis with each column of subplots
plt.subplot(1, 2, 1)
x = plt.plot([1,2,3,4])
y = plt.plot([6,6,7,7.3])
m = plt.plot([5.5,6.8,7.6,10])
plt.legend(['2010', '2018', '2022'])
plt.title('Sales', fontsize=30, loc = 'center', color='b')

# Note that this is the same as
plt.subplot(1, 2, 2)

w = np.random.randn(100)
z = np.random.randn(100)
plt.scatter(w,z, alpha=0.4, s=50);
